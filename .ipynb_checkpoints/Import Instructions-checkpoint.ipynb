# %%
from sqlalchemy import create_engine
from config import db_password
import pandas as pd

# %%
db_location = 'probowl.cq2v3ncckm8b.us-east-2.rds.amazonaws.com'

# %%
db_string = f"postgresql://postgres:{db_password}@{db_location}/postgres"

# %%
engine = create_engine(db_string)

# %%
df = pd.read_sql_table('total_stats_2019', engine)

# %%
df.head()
# Out:
#            player   tm  age pos   g  gs  cmp  pass_att  pass_yds  pass_td  \
# 0  Jameis Winston  TAM   25  QB  16  16  380       626      5109       33
# 1    Dak Prescott  DAL   26  QB  16  16  388       596      4902       30
# 2      Jared Goff  LAR   25  QB  16  16  394       626      4638       22
# 3   Philip Rivers  LAC   38  QB  16  16  390       591      4615       23
# 4       Matt Ryan  ATL   34  QB  15  15  408       616      4466       26
#
#    ...  gwd  rush_att  rush_yds  rush_td  tgt  rec  rec_yds  rec_td  fmb  \
# 0  ...    2        59       250        1    0    0        0       0    0
# 1  ...    0        52       277        3    0    0        0       0    0
# 2  ...    2        33        40        2    0    0        0       0    0
# 3  ...    2        12        29        0    0    0        0       0    0
# 4  ...    2        34       147        1    0    0        0       0    0
#
#    pro_bowl
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#
# [5 rows x 22 columns]
